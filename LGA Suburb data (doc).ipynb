# %% [markdown]
# # Scraping wikipedia for Suburb summary and images
#
# ## Goal
# Swapping out the planet images and descriptions in Endless Sky with suburbs in Victoria, using publicly available images and wikipedia summary
#
# ## Method
# The list of suburbs per LGA were compiled from this [wikipedia page]('https://en.wikipedia.org/wiki/List_of_localities_in_Victoria'), partially by web scraping and partially manually.
#
# They are stored in: `Working LGA Suburbs sheet.xlsx`
# There are 79 LGAs and we made an arbitray decision to pick 4 suburbs/LGA -> the 316 suburbs

# %% [markdown]
# ### Libraries used
# - pandas: dataframe, excel read/write functionality
# - requests: web site access
# - Wikipedia APIs: search wikipedia for pages, get summary and image list. Found two, tried both in the following order
#   - [wiki-api](https://github.com/richardasaurus/wiki-api)
#   - [wikipedia](https://wikipedia.readthedocs.io/en/latest/quickstart.html#quickstart)
#   - Used `wiki-api` initially for suburbs summary and image grab, but it only grabs the low resolution thumbnails of the main article image. I switched to the `wikipedia` which gives the full list of images on each article
# - re: regexp

# %%
import pandas as pd

# %%
from lxml import html, etree
import requests

# %% [markdown]
# Read in the LGA suburb list

# %%
dat = pd.read_excel(r'Working LGA Suburbs sheet.xlsx')

# %%
dat = dat.set_index('Local government')

# %%
from wikiapi import WikiApi
import wikipedia as wk
import re

# %%
wiki = WikiApi()

# %%
flatsuburb=dat.stack()

# %%
# Obsolete function - used initial with wiki-api
import urllib.parse as up
def suburb_image(row):
    suburb,url = [row['index'],row['source']]
    mobj = re.search(r'.*\.(.*)',up.urlparse(url).path)
    if mobj:
        return '{0}.{1}'.format(suburb,mobj.group(1).lower())
    else:
        return url

# %%
# Image downloading function copy/pasted from stackoverflow, added primitive exception handling
def download_image(url,fname):
    try:
        r = requests.get(url, stream=True)
        if r.status_code == 200:
            with open(fname, 'wb') as f:
                for chunk in r:
                    f.write(chunk)
        return 'Done'
    except:
        print(url+": something's wrong")
        return 'null'

# %%
# placeholder suburb image
hawaii_image = r'https://www.google.com.au/imgres?imgurl=https%3A%2F%2Fupload.wikimedia.org%2Fwikipedia%2Fcommons%2F8%2F8d%2FNa_Pali_Coast%2C_Kauai%2C_Hawaii.jpg&imgrefurl=https%3A%2F%2Fen.m.wikipedia.org%2Fwiki%2FHawaiian_culture&docid=MrshDp0UcD3_nM&tbnid=rDnsZuzMjRMggM%3A&w=1761&h=1173&bih=747&biw=760&ved=0ahUKEwiS5sTB4JrOAhUHpJQKHay-AYgQMwgcKAEwAQ&iact=mrc&uact=8'
def spicker(hitlist):
    viclist = [hit for hit in hitlist if re.search(r'victoria',hit,flags=re.I)]
    if len(viclist)>0:
        return viclist[0]
    elif len(hitlist)>0:
        return hitlist[0]
    else:
        return None
    
def wiki_suburb_search(suburb):
    results = wiki.find(suburb+' victoria')
    article = wiki.get_article(spicker(results))
    print(article)
    if results:
        return [article.summary,article.image]
    else:
        return ['null','null']
    
def wiki_suburb_search2(suburb):
    try:
        results = wk.search(suburb+' victoria')
        a = wk.page(spicker(results))
        #print(results)

        if results:
            img_list = sorted(a.images,key=avoid)
            img_url = img_list[0]
            mobj = re.search(r'.*\.(.*)',up.urlparse(img_url).path)
            img_fn = '{0}.{1}'.format(suburb,mobj.group(1).lower())
            try:
                fdict[img_fn]
                img_status = 'Done'
            except:
                img_status = download_image(img_url,img_fn)
            return [a.url, a.summary, img_url, img_fn, img_status, str(img_list)]
        else:
            return ['null']*6
    except:
        return ['null']*6
    
def avoid(instr):
        for i,x in enumerate(['png', 'map', 'logo', 'red_pog', 'svg']):
            if re.search(x,instr,flags=re.I):
                return i+2
        return 0

def img_cmp(a,b):
    if avoid(a) < avoid(b):
        return 1
    else:
        return -1

# %% [markdown]
# ## Code testing

# %%
a = wiki_suburb_search2(flatsuburb[7])
# Out:
# ['Lake Bolac, Victoria', 'The Exploders', 'Lake Bolac stone arrangement', 'Mininera & District Football League', 'Hopkins River', 'Victoria River (Victoria)', 'Plenty River (Victoria)', 'Calder River (Victoria)', 'Little River (Moroka River, Victoria)', 'Glenelg Highway']

# %%
flatsuburb[6]
# Out:
# 'Taytoon'

# %%
results = wk.search('Taytoon'+' Victoria')

# %%
import os
fdict = dict([[f,1] for f in os.listdir()])

# %% [markdown]
# ## Running the wikipedia scraper

# %%
suburbdata=[wiki_suburb_search2(suburb) for suburb in flatsuburb]
# Out:
# ['Myrtleford', 'Richard Colbeck', 'Shire of Myrtleford', 'County of Bogong', 'Myrtleford railway station', 'Curing of tobacco', 'Ross Milne', 'Battle of Mont Saint-Quentin', 'Chloe McConville', 'Tobacco']
# ['Bright, Victoria', 'Bright', 'Shire of Bright', 'Christian Geiger', 'County of Bogong', '87.6 FM', 'Audax Alpine Classic', 'Tourist gateway', 'Centenary Test', 'Phillip Tracey']
# ['Porepunkah', 'Porepunkah Airfield', 'Porepunkah railway station', 'County of Bogong', 'Ovens River', 'Buckland River (Victoria)', 'Mount Selwyn (mountain)', 'List of airports in Victoria (Australia)', 'Warrnambool Airport', 'Portland Airport (Victoria)']
# ['Tawonga, Victoria', 'Mount Beauty, Victoria', 'Electoral district of Benambra', 'Shire of Bright', 'Kiewa Valley Highway', 'Tallangatta & District Football League', 'Kiewa River', 'Great Alpine Road', 'Tea in Australia', 'List of localities in Victoria']
# ['Ararat, Victoria', 'Dunneworthy, Victoria', 'Ararat Football Club', 'Hopkins Correctional Centre (Ararat)', 'Challicum Hills Wind Farm', 'Marian College (Ararat)', 'Jim Mooney (politician)', 'J Ward', 'Rural City of Ararat', 'Frederick Scherger']
# ['Moyston, Victoria', 'Grevillea microstegia', 'Claire Baxter', 'Mininera & District Football League', 'Mount Lubra bushfire', 'Geology of Victoria', 'Rural City of Ararat', 'Nelson Province (Australia)', 'Willaura', 'Goldfields region of Victoria']
# ['Lake Bolac, Victoria', 'The Exploders', 'Lake Bolac stone arrangement', 'Mininera & District Football League', 'Hopkins River', 'Victoria River (Victoria)', 'Plenty River (Victoria)', 'Calder River (Victoria)', 'Little River (Moroka River, Victoria)', 'Glenelg Highway']
# ['Wendouree, Victoria', 'Lake Wendouree, Victoria', 'Australian Rowing Championships', 'Lake Wendouree', 'Electoral district of Wendouree', 'Ballarat Grammar School', 'City of Ballaarat', 'Hawthorn Tramways Trust', 'Lakeside Mental Hospital', 'Eureka Stadium']
# ['Sebastopol, Victoria', 'Sebastopol', 'Borough of Sebastopol', 'James Collins (public servant)', 'Jimmy Aitken', 'Prahran and Malvern Tramways Trust', 'Phoenix P-12 Community College', 'Victoria Cross', 'Sebastopol Football Netball Club', 'Sebastopol (mortar)']
# ['Alfredton, Victoria', 'Alfredtown', 'Alfredton', 'Will Dyson', 'Alfredton, New Zealand', 'Ballarat Football Club', 'Electoral district of Wendouree', 'Lake Gardens, Victoria', 'Cardigan, Victoria', 'Shire of Ballarat']
# ['Ballarat Central', 'ABC South West Victoria', 'ABC Kimberley', 'ABC Shepparton', 'ABC Mildura Swan Hill', 'ABC Katherine', '1233 ABC Newcastle', '97.3 ABC Illawarra', '936 ABC Hobart', 'List of ABC radio stations']
# ['Argentina at the 1991 Pan American Games', 'Miss Paraguay', 'Rosanna', 'List of Spanish films of 1999', 'Goya Award for Best Supporting Actress', 'Miss Venezuela 1981', "Football at the 2000 Summer Olympics – Women's team squads", '10th Goya Awards', 'Operación Triunfo (Argentinian TV series)', '16th Goya Awards']
# ['Viewbank, Victoria', 'Viewbank College', 'Stawell Gift', 'List of high schools in Melbourne', 'Rosanna, Victoria', 'Heidelberg, Victoria', 'Division of Jagajaga', 'City of Heidelberg', 'River Gum Walk Trail', 'Bulleen, Victoria']
# ['Heidelberg Heights, Victoria', 'Heidelberg West, Victoria', 'Heidelberg, Victoria', 'City of Heidelberg', 'Northern Football League (Australia)', 'National Premier Leagues Victoria', 'Bellfield, Victoria', 'Olympic Park (Village)', 'Macleod, Victoria', 'Football Federation Victoria']
# ['Yallambie, Victoria', 'Electoral district of Bundoora', 'Watsonia, Victoria', 'Macleod, Victoria', 'Division of Jagajaga', 'River Gum Walk Trail', 'Simpson Barracks', 'City of Heidelberg', 'Rosanna, Victoria', 'Viewbank, Victoria']
# ['Benalla', 'Benalla Football Club', 'Benalla Airport', 'Hector Waller', 'Winton, Victoria', 'FCJ College Benalla', 'Oaklands railway line, New South Wales', 'No. 11 Elementary Flying Training School RAAF', 'Benalla Ensign', 'Winton Motor Raceway']
# ['Devenish, Victoria', 'Devenish', 'County of Moira', 'List of Trinidadian football transfers 2010–11', 'List of oldest buildings and structures in Toronto', 'Tiger Devenish', 'Charlie Devenish', 'Olivia Mariamne Devenish', 'Major Plains, Victoria', 'Frank Meares']
# ['Goorambat, Victoria', 'County of Moira', 'Benalla & District Football League', 'Rural City of Benalla', 'Tom Trewin', 'Ovens & King Football League', 'Shire of Benalla', 'Edward Cleary (Australian politician)', 'Oaklands railway line, Victoria', 'Better Farming Train (Victoria)']
# ['Aberfeldy', 'Aberfeldy, Victoria', 'Aberfeldie, Victoria', 'Mount Selma', 'Florence Ada Mary Lamb Polson', 'Aberfeldy, Perth and Kinross', 'John Dwyer (Australian judge)', 'Drymophila cyanocarpa', '2012–13 Australian bushfire season', 'Aberfeldy River']
# ['Athlone, Victoria', 'Fairway Markets', 'Athlone (disambiguation)', 'List of Irish place names in other countries', 'Athlone', 'Queen Victoria', 'Princess Alice, Countess of Athlone', 'Alexander Cambridge, 1st Earl of Athlone', 'Princess Beatrice of the United Kingdom', 'County Westmeath']
# ['Buln Buln, Victoria', 'Shire of Buln Buln', 'County of Buln Buln', 'Buln Buln', 'List of reduplicated Australian place names', 'Phil Manning (footballer)', 'Rural City of Warragul', 'Ellinbank & District Football League', 'County of Evelyn, Victoria', 'Shire of Narracan']
# ['Darnum, Victoria', 'County of Buln Buln', 'Nilma, Victoria', 'Ellinbank & District Football League', 'Moe River', 'Rural City of Warragul', 'Jason Davenport', 'Shire of Baw Baw', 'List of Australian rules football competitions in Victoria', 'Princes Freeway']
# ['Brighton East, Victoria', 'City of Brighton', 'Brighton, Victoria', 'Brighton Southern Cross', 'Vernon Ransford', 'John Dallachy', '88.3 Southern FM', 'Brighton Cemetery', 'Elsie Deane', 'Rob Quiney']
# ['Sandringham, Victoria', 'Jim Baird', 'Sandringham Sabres', 'Electoral district of Sandringham', 'Brett Roneberg', 'Sandringham', 'Jon Holland', 'Trevor Barker Oval', 'Peter R. Bell', 'Epacris impressa']
# ['Moorabbin, Victoria', 'Moorabbin Airport', 'King Island Airlines', 'Silk–Miller police murders', 'Electoral district of Moorabbin', 'Johnny Riley', 'Electoral district of Mooroolbark', 'Mark Cleary (cricketer)', 'Federal Football League', 'King Island Airport']
# ['Mordialloc, Victoria', 'Siah Kola, Nur', 'Parkdale Secondary College', 'Winnie George', 'Electoral district of Mordialloc', 'Federal Football League', 'City of Mordialloc', 'Sharni Layton', 'Parkdale, Victoria', 'Reg Burgess']
# ['Baddaginnie, Victoria', 'Baddaginnie railway station', 'Frederick Cook (Australian politician)', 'List of closed railway stations in Victoria', 'Rural City of Benalla', 'Benalla railway station', 'Shire of Benalla', 'Old Hume Highway', 'North East railway line', 'Violet Town railway station']
# ['Benalla', 'Benalla Football Club', 'Benalla Airport', 'Hector Waller', 'Winton, Victoria', 'FCJ College Benalla', 'Oaklands railway line, New South Wales', 'No. 11 Elementary Flying Training School RAAF', 'Benalla Ensign', 'Winton Motor Raceway']
# ['Devenish, Victoria', 'Devenish', 'County of Moira', 'List of Trinidadian football transfers 2010–11', 'List of oldest buildings and structures in Toronto', 'Tiger Devenish', 'Charlie Devenish', 'Olivia Mariamne Devenish', 'Major Plains, Victoria', 'Frank Meares']
# ['Goorambat, Victoria', 'County of Moira', 'Benalla & District Football League', 'Rural City of Benalla', 'Tom Trewin', 'Ovens & King Football League', 'Shire of Benalla', 'Edward Cleary (Australian politician)', 'Oaklands railway line, Victoria', 'Better Farming Train (Victoria)']
# ['Balwyn North', 'Melbourne tram route 48', 'Balwyn High School', 'Rowena Webster', 'Steve Hooker', 'Macleay Park', 'Koonung Creek Reserve', 'Balwyn, Victoria', 'Greythorn Park', 'Gordon Barnard Reserve']
# ['Glen Iris, Victoria', 'Enid Moodie Heddle', 'Associated Public Schools of Victoria', 'Daniel Berg (baseball)', 'Alan Charlesworth', 'Colin McDonald (Australian cricketer)', 'Fred Finch (footballer)', 'Beryl Elaine Jacka', 'Glen Iris', 'Electoral district of Knox']
# ['Hawthorn East, Victoria', 'Hawthorn, Victoria', 'Percival Serle', 'City of Hawthorn', 'Amcor', 'Curtis Reid', 'Swinburne Senior Secondary College', 'Bakers Delight', 'List of mayors of Hawthorn, Victoria', 'Hawthorn']
# ['Kew East, Victoria', 'Kew, Victoria', 'Roman Catholic Archdiocese of Melbourne', 'City of Kew', 'Calder Freeway', 'Princes Highway', 'Umbrella Entertainment', 'Peter Van Miltenburg', 'Western Freeway (Victoria)', 'Elaine Bray']
# ['Albion, Victoria', '2010–11 Stirling Albion F.C. season', '2013–14 Hartlepool United F.C. season', 'Shōrin-ryū Shidōkan', '2010–11 Hartlepool United F.C. season', 'Yorkshire Football League', '2010–11 Ross County F.C. season', '2013–14 Burton Albion F.C. season', 'Wincham Park', 'Albion (disambiguation)']
# ['Sunshine North, Victoria', 'Sunshine West, Victoria', 'Sunshine, Victoria', 'City of Sunshine', 'Judith Graley', 'Jodi Dannatt', 'John McQuilten', 'Lorraine Kutcher', 'Formula E (disambiguation)', '2009 Victorian Premier League']
# ['Kealba, Victoria', 'The Recruit (TV series)', 'Electoral district of St Albans', 'Division of Maribyrnong', 'City of Brimbank', 'Sunshine North, Victoria', 'City of Keilor', 'St Albans, Victoria', 'Keilor Downs, Victoria', 'Keilor Park, Victoria']
# ['Delahey, Victoria', '774 ABC Melbourne', 'Electoral district of Sydenham', 'Hillside, Victoria', 'Division of Gorton', 'City of Brimbank', 'Taylors Lakes, Victoria', 'Keilor Downs, Victoria', 'Sydenham, Victoria', 'Taylors Hill, Victoria']
# ['Ballapur, Victoria', 'County of Karkarooc', 'Birchip West, Victoria', 'Warmur, Victoria', 'Reedy Dam, Victoria', 'Karyrie, Victoria', 'Wilkur, Victoria', 'Shire of Birchip', 'List of localities in Victoria', 'Index of India-related articles']
# ['Banyan, Victoria', 'Banyan', 'Myall, Victoria (Shire of Buloke)', 'Willangie, Victoria', 'Boigbeat, Victoria', 'List of tallest buildings in Hong Kong', 'Berriwillock', 'Sea Lake', 'Albert Wendt', 'Shire of Wycheproof']
# ['Berriwillock', 'County of Tatchera', 'Tyrrell Football League', 'Berriwillock railway station', 'Boigbeat, Victoria', 'Sutton, Victoria', 'Corack East, Victoria', 'Banyan, Victoria', 'Springfield, Victoria', 'Willangie, Victoria']
# ['Bimbourie, Victoria', 'County of Karkarooc', 'Nyarrin, Victoria', 'Lake Tyrrell, Victoria', 'Ninda, Victoria', 'Nandaly, Victoria', 'Pier Milan', 'List of localities in Victoria']
# ['Bamawm', 'George Rankin', 'County of Bendigo', 'Lockington, Victoria', 'David A. Clarke (footballer)', 'Heathcote District Football League', 'Geoff Barber', 'List of Australian rules football competitions in Victoria', 'List of localities in Victoria', 'Bendigo Football League']
# ['Colbinabbin', 'County of Rodney, Victoria', 'Heathcote District Football League', 'Briagolong railway line', 'Thorpdale railway line', 'Shepparton railway line', 'Eaglehawk–Inglewood railway line', 'Shire of Waranga', 'Bairnsdale V/Line rail service', 'Kulwin railway line']
# ['Corop, Victoria', 'COROP', 'County of Rodney, Victoria', 'Stellerite', 'Shire of Waranga', 'Heathcote wine region', 'List of localities in Victoria', 'Sittard', 'Kyabram & District Football League', 'List of Country Fire Authority brigades']
# ['Echuca', 'Deniliquin railway line', 'Echuca Airport', 'George Bazeley', 'Echuca College', "St. Joseph's College, Echuca", 'HMAS Echuca', 'City of Echuca', 'Division of Echuca', 'The Tech']
# ['Cockatoo, Victoria', 'Cockatoo (disambiguation)', 'Ramingining, Northern Territory', 'Come Midnight Monday', 'Red-tailed black cockatoo', 'Yellow-tailed black cockatoo', 'Cockatoo', "Major Mitchell's cockatoo", 'Gang-gang cockatoo', 'Glossy black cockatoo']
# ['Gembrook, Victoria', 'County of Mornington', 'Electoral district of Gembrook', 'December 18', 'Robert Crowe', 'Scouting and Guiding in Victoria', 'E. E. Kurth', 'List of Scouting memorials', 'Gembrook railway station', 'Electoral results for the district of Gembrook']
# ['Bunyip North, Victoria', 'Bunyip, Victoria', 'Bunyip', 'County of Mornington', 'Altar', 'John Vickery (artist)', 'Australian Aboriginal mythology', 'Bunyip River', 'Bunyip State Park', 'Ellinbank & District Football League']
# ['Garfield North, Victoria', 'Garfield, Victoria', 'Garfield (disambiguation)', 'James A. Garfield', 'List of characters in the Garfield franchise', 'Garfield and Friends', 'Garfield railway station', 'Garfield, New Jersey', 'Garfield Range', 'Ellinbank & District Football League']
# ['Clyde North, Victoria', 'Clyde, Victoria', 'Casey Warriors', 'Clyde', '2008–09 Ross County F.C. season', '2006–07 Ross County F.C. season', 'Calendar Boys', 'Langside College', 'Great Scottish Run', 'Glasgow Victoria Infirmary']
# ['Hallam, Victoria', 'Hallam', 'Rise Up Australia Party', 'PCW', 'Undertow (Mark Seymour album)', 'Sri Lankan Australians', 'Mitre 10', 'Phil Irving', 'Vincent Motorcycles', 'Victoria Hall Limited']
# ['Warneet, Victoria', 'Chinaman Island', 'Cannons Creek, Victoria', 'Quail Island (Victoria)', 'Tooradin, Victoria', 'Cranbourne railway station', 'City of Casey', 'Devon Meadows, Victoria', 'Cranbourne Transit', 'Western Port']
# ['Harkaway, Victoria', 'Harkaway', 'Deloris', 'Electoral district of Narre Warren North', 'Officer, Victoria', 'Guys Hill, Victoria', 'Beaconsfield Upper, Victoria', 'Berwick, Victoria', 'Narre Warren North, Victoria', 'Beaconsfield, Victoria']
# ['Adelaide Lead, Victoria', 'Adelaide', 'Adelaide Oval', 'Port Adelaide Football Club', 'O-Bahn Busway', 'Showdown (AFL)', 'John Cahill (footballer)', 'Adelaide Football Club', 'Richard Douglas (footballer)', 'Adelaide Street Circuit']
# ['Alma, Victoria', 'Clarence Herbert Smith', 'Waukaringa, South Australia', 'Alma', 'Arthur Hiller', 'Christine Couzens', 'George Locke', 'Don McKellar', 'Frances Oldham Kelsey', 'Wilbur K. Howard']
# ['Amherst, Victoria', 'Amherst', 'Carty Salmon', 'Nova Scotia Trunk 6', 'List of subjects related to the Quebec independence movement', 'Amherst, Nova Scotia', 'Baron Amherst of Hackney', 'Emily Dickinson', 'Port-la-Joye–Fort Amherst', 'Nova Scotia Route 204']
# ['Bung Bong, Victoria', 'Bung (disambiguation)', 'Glenmona Bridge', 'Avoca railway line', 'County of Talbot, Victoria', 'Pyrenees Highway, Victoria', 'Avoca, Victoria', 'List of localities in Victoria', 'Adelaide Lead, Victoria', 'List of ethnic slurs']
# ['Alvie, Victoria', 'Alvie', 'Alvie Football Netball Club', 'Colac & District Football League', 'Balintore, Victoria', 'Almurta, Victoria', 'Mount Waverley, Victoria', 'Briagolong railway line', 'Thorpdale railway line', 'List of closed railway stations in Victoria']
# ['Apollo Bay', 'Paul Couch', 'Neil Melville', 'Golf in Australia', 'Kulin', 'Melba Gully State Park', 'Seal point', 'Ace Radio', 'Amphitrite', 'The Vasco Era']
# ['Beeac', 'Jack Carney', 'Bill Johnston (cricketer)', 'February 1922', 'Bill Johnston with the Australian cricket team in England in 1948', 'Arthur Pink (footballer)', 'The Farmer Wants a Wife (Australian TV series)', 'Banksia marginata', 'List of Country Fire Authority brigades', 'Lake Beeac']
# ['Beech Forest, Victoria', 'Cliff Young (athlete)', 'Sydney to Melbourne Ultramarathon', 'Cliff Young', 'Railway station layout', 'Sport in rural and regional Australia', 'Beech Forest railway station', 'Lophozonia cunninghamii', 'Crowes railway line', 'Central Highlands (Victoria)']
# ['Camperdown, Victoria', 'The Camperdown Chronicle', 'Camperdown', 'Cameron Rahles-Rahbula', 'James Harrison (Australian governor)', 'Matthew Pallister', 'Town of Camperdown', 'Brydon Coverdale', 'Josh Hose', 'Geoffrey Wickham']
# ['Cobden, Victoria', 'Jane Robinson (rower)', 'Cobden', 'John Francis Skjellerup', 'George Skellerup', 'List of airports by ICAO code: Y', 'Woolton', 'SunRice', 'Richard Cobden', 'Stawell Gift']
# ['Derrinallum', 'Derrinallum P12 College', 'P12', 'Geotourism', 'Daniel Nicholson', 'Mount Elephant', 'Mininera & District Football League', 'Lismore, Victoria', 'Shire of Hampden', 'Hamilton Highway']
# ['Foxhow, Victoria', 'Shire of Hampden', 'Lake Corangamite', 'Hamilton Highway', 'Terang', 'List of localities in Victoria', 'List of road routes in Victoria']
# ['Reservoir, Victoria', 'Peter Watson (politician)', 'Reservoir High School (Victoria)', 'Reservoir (disambiguation)', 'Electoral district of Reservoir', 'West Preston Lakeside Football Club', 'Nicholas Bartlett', 'Merrilands College', 'Lauriston Reservoir', "O'Shannassy Reservoir"]
# ['City of Preston (Victoria)', 'Preston, Victoria', 'Melbourne tram route 11', 'Preston', 'Preston City Oval', 'Preston & Northcote Community Hospital', 'Electoral district of Preston', 'Rob Leota', 'Ken McFadyen', 'Oenology']
# ['Kingsbury, Victoria', 'Kingsbury', 'Kingsbury (disambiguation)', 'Bruce Kingsbury', 'List of Australian Victoria Cross recipients', "Old St Andrew's Church, Kingsbury", 'Kingsbury (surname)', 'List of Victoria Cross recipients (G–M)', 'Municipal Borough of Wembley', 'List of Second World War Victoria Cross recipients']
# ['Thornbury, Victoria', 'Distance Education Centre, Victoria', 'Marlene Kairouz', 'John Cain Memorial Reserve', 'Northcote City FC', 'Thornbury', 'Lawn bowls at the 2006 Commonwealth Games', 'Ronnie di Stasio', 'List of breweries in Australia', 'Peter Carnley']
# ['Anglers Rest, Victoria', 'Omeo Highway', 'Big River (Mitta Mitta River, Victoria)', 'Bundara River', 'Cobungra River', 'Mitta Mitta River', '2003 Eastern Victorian alpine bushfires', 'Lisa Marie Varon', 'Falls Creek, Victoria', 'Bushfires in Victoria']
# ['Bairnsdale Airport', 'The Advertiser', 'The Advertiser (Bairnsdale)', 'Salesian College', 'Bairnsdale', 'Bruce Morrison (footballer)', 'Bairnsdale Secondary College', 'Hal Porter', 'Shire of Bairnsdale', 'Jon Ballantyne (footballer)']
# ['Bemm River, Victoria', 'Bemm River', 'McKenzie River (Victoria)', 'Little River (Sydenham Inlet, East Gippsland)', 'Ada River (East Gippsland, Victoria)', 'Goolengook River', 'Combienbar River', 'Errinundra River', 'Arte River', 'Little Goolengook River']
# ['Benambra, Victoria', 'Mount Gibbo', 'County of Benambra', 'Electoral district of Benambra', 'Drought', 'Gibbo River', 'Electoral results for the district of Benambra', 'Omeo & District Football League', 'Northern Victoria Region', 'County of Bogong']
# ['Langwarrin, Victoria', 'Langwarrin South, Victoria', 'Leisureland Fair', 'Mulberry Hill', 'County of Mornington', 'Bayside Christian College', 'Emma Booth (equestrian)', 'Woodleigh School, Melbourne', 'Olearia lirata', 'Thelionema caespitosum']
# ['Frankston South, Victoria', 'John Paul College (Melbourne)', 'Karingal Hub Shopping Centre', 'St John of God Frankston Rehabilitation Hospital', 'Frankston', 'Frankston Football Club', 'Frankston North, Victoria', 'Tony Simpson', 'Frankston, Victoria', 'John Conway (cricketer)']
# ['Karingal, Victoria', 'Karingal Hub Shopping Centre', 'Justin Peckett', 'McClelland College', 'Mornington Peninsula Nepean Football League', 'South East Football Netball League', 'Cranbourne Transit', 'Peninsula Bus Lines', 'Darren Hulme', 'Geoff Amoore']
# ['Carrum Downs, Victoria', 'Carrum Downs Secondary College', 'Indian Australians', 'Business park', 'Mitch White', 'Ritchies Stores', 'Peninsula Link', 'Vik Grujic', 'Electoral district of Carrum', 'Chelsea Province']
# ['Cohuna, Victoria', 'Shire of Cohuna', 'County of Gunbower', 'Stuart Appleby', 'Ray Garby', 'Evangelical Presbyterian Church (Australia)', '2007 Presidents Cup', 'Bruce Calverley', 'Isaac Barr', 'Cohuna railway line']
# ['Kerang', 'Stony Crossing, New South Wales', 'Kerang Airport', 'Stony Crossing railway line', 'Wemba-Wemba', 'Leaghur State Park', 'Kerang Technical High School', 'Shire of Kerang', 'Borough of Kerang', 'County of Gunbower']
# ['Koondrook', 'Alexander Arbuthnot (paddle steamer)', 'Roy Higgins', 'Barham, New South Wales', 'Brent Guerra', 'George Ilsley', 'List of Royal Hotels in Australia', 'Murray–Darling steamboat people', 'Kerang–Koondrook Tramway', 'Barapa Barapa']
# ['Leitchville, Victoria', 'Jeff Fehring', 'Murray Valley Highway', 'Central Murray Football League', 'Cohuna railway line', 'Heathcote District Football League', 'Shire of Cohuna', 'Murrabit', 'Mount Hope (Victoria)', 'List of Australian rules football competitions in Victoria']
# ['Bentleigh East, Victoria', 'Bentleigh, Victoria', 'Federal Football League', 'Electoral district of Bentleigh', 'Nick Staikos', 'Roger Ellingworth', 'Basil McCormack', 'Bentleigh Secondary College', 'St James College (Victoria)', 'Max Spittle']
# ['Caulfield, Victoria', 'Caulfield East, Victoria', 'Caulfield North, Victoria', 'Glen Eira Town Hall', 'Caulfield South, Victoria', 'Federal Football League', 'Rhys Gemmell', '2nd Light Tank Company (Australia)', 'Electoral district of Caulfield', 'James Newland']
# ['Carnegie, Victoria', 'Barak Mizrachi', 'Carnegie', 'Hector Waller', 'Darwin Triple Crown', 'Phillip Island SuperSprint', 'Squire Reid', '9th Parliament of Ontario', '8th Parliament of Ontario', '10th Parliament of Ontario']
# ['Brighton East, Victoria', 'Mark Turnbull', 'Brighton Secondary College', 'Marc Polmans', 'Noni Hazlehurst', 'Upper Middle Bogan', "St Leonard's College (Melbourne)", 'Haileybury (Melbourne)', 'List of government schools in Victoria, Australia', 'Electoral district of Brighton']
# ['Allestree, Victoria', 'Allestree', 'Shire of Heywood', 'Sir William Evans, 1st Baronet', 'List of electoral wards in Derbyshire', 'Derby', 'Quarndon', 'William Gisborne', 'Alan Bates', 'Convincing Ground']
# ['Cape Bridgewater', 'Tarragal Caves', 'List of shipwrecks in 1858', 'HMS Sappho (1837)', 'Bridgewater On Loddon, Victoria', 'List of marine animals of Australia (temperate waters)', 'Lunenburg West', 'Discovery Bay Coastal Park', 'Discovery Bay Marine National Park', 'Discovery Bay (Australia)']
# ['Casterton, Victoria', 'Casterton News', 'Acacia exudans', 'William Macmahon Ball', 'Alexander McGregor Grant', 'Casterton', 'Russell Johnston (footballer)', 'Mary Gilmore', 'Bill Forsyth (diplomat)', 'Ernest James Stevens']
# ['Condah', 'Reg Saunders', 'Stawell Gift', 'Cedric Kellway', 'Graeme Gunn', 'Australian residential architectural styles', 'Framlingham, Victoria', 'Lake Martin (Victoria)', 'Gunditjmara', 'Budj Bim']
# ['Bannockburn, Victoria', 'Leigh Harding', 'Bannockburn Football & Netball Club', 'Shire of Bannockburn', 'Bannockburn (disambiguation)', 'Roy Longmore', 'Golden Plains Shire', 'Geelong & District Football League', 'Shire of Corio', 'Gheringhap, Victoria']
# ['Berringa, Victoria', 'County of Benambra', 'Bill Welsh (footballer, born 1908)', 'Golden Plains Shire', 'Enfield, Victoria', 'Dereel, Victoria', 'Cape Clear, Victoria', 'List of former Australian rules football competitions in Victoria', 'Colac-Ballarat railway line', 'Victorian gold rush']
# ['Cape Clear, Victoria', 'Cape Clear', 'List of Irish place names in other countries', 'Cape Town', 'Cape York Peninsula', 'George, Western Cape', 'Northern Cape', 'Epacris impressa', 'Terra Nova Expedition', 'Cape Breton Regional Municipality']
# ['Corindhap, Victoria', 'County of Grenville, Victoria', 'William Hixon McDonald (senior)', 'William Hixon McDonald (junior)', 'Thomas Ulick Burke', 'Lexton Plains Football League', 'Electoral district of Buninyong', 'Rokewood, Victoria', 'Central Highlands Football League', 'Rokewood Junction, Victoria']
# ['Eaglehawk, Victoria', 'Eaglehawk Football Club', 'Electoral district of Eaglehawk', 'Robert McKenzie (Australian politician)', 'Electoral district of Korong and Eaglehawk', 'Borough of Eaglehawk', "Mulga Bill's Bicycle", 'Eaglehawk (disambiguation)', 'Michael Considine', 'Darcy Lear']
# ['California Gully, Victoria', 'California (disambiguation)', 'Edward Heitmann', 'Long Gully, Victoria', 'Maiden Gully, Victoria', 'Epsom, Victoria', 'Quarry Hill, Victoria', 'Kennington, Victoria', 'Golden Square, Victoria', 'Axe Creek, Victoria']
# ['Epsom, Victoria', 'Electoral district of Ballarat South', 'Electoral district of Ballarat North', 'Electoral district of Ballarat', 'Carwarp, Victoria', 'Emma Dean (chef)', 'Frank Brennan (politician)', 'Electoral results for the district of Ballarat South', 'Electoral results for the district of Ballarat North', 'Noel Beaton']
# ['Axedale', 'County of Bendigo', 'Dale (place name element)', "O'Keefe Rail Trail", 'Electoral district of Bendigo East', 'Shire of Strathfieldsaye', 'City of Greater Bendigo', 'Quarry Hill, Victoria', 'Kennington, Victoria', 'Epsom, Victoria']
# ['Keysborough, Victoria', 'Chandler High School', 'Keysborough Secondary College', 'Springvale White Eagles FC', 'Electoral district of Keysborough', 'Lighthouse Christian College', 'Australia Roller Hockey National Championship', 'Sanford L.P.', 'James McSweeney', 'Parkmore Shopping Centre']
# ['Springvale South, Victoria', 'Springvale, Victoria', 'Westall Road', 'Killester College', 'Electoral district of Springvale', 'Noble Park Secondary College', 'Springvale Botanical Cemetery', 'Drivetrain Systems International', 'Federal Football League', 'Keysborough Secondary College']
# ['Bangholme, Victoria', 'Eastern Treatment Plant', 'Electoral district of Lyndhurst', 'Chelsea Heights, Victoria', 'Dandenong South, Victoria', 'Keysborough, Victoria', 'Patterson River', 'City of Greater Dandenong', 'Dandenong Creek', 'City of Springvale']
# ['Noble Park, Victoria', 'Noble Park North, Victoria', 'Carwatha College', 'Electoral district of Noble Park', 'Federal Football League', 'Mount Gibbo', 'Nicholson River (Victoria)', 'Timbarra River (Victoria)', 'Bob Windle', 'Bundara River']
# ['Anakie, Victoria', 'Fairy Park', 'Dan Robinson (singer)', 'County of Grant, Victoria', 'Grevillea rosmarinifolia', 'Anakie', 'List of schools in Geelong', 'Terinu', 'Geelong & District Football League', 'Electoral district of Lara']
# ['Corio, Victoria', "Gavan O'Connor", 'Point Wilson, Victoria', 'Shire of Corio', 'Corio', 'County of Grant, Victoria', 'Cowie', 'Division of Corio', 'Andrew Scott (cricketer)', 'Geelong Grammar School']
# ['Belmont, Victoria', 'Belmont High School (Victoria)', 'Belmont Lions Sports Club Football Club', 'Joe Sellwood', 'Oberon High School', 'Forever Now (Cold Chisel song)', 'Cold Chisel (album)', 'Swingshift', 'Welshpool, Western Australia', 'Geelong Football League']
# ['Bellarine, Victoria', 'Marcus Hill, Victoria', 'Lake Lorne', 'Curlewis, Victoria', 'Lake Victoria (Victoria)', 'Rural City of Bellarine', 'Drysdale Football Club', 'Queenscliff Music Festival', 'County of Grant, Victoria', 'Electoral district of Bellarine']
# ['Arcadia, Victoria', 'Arcadia railway station', 'County of Moira', 'Arcadia (disambiguation)', 'Goulburn Valley Freeway', 'MV Arcadia (2004)', 'Arcadia, California', 'Arcadia Planitia', 'SS Arcadia (1953)', 'A Year in Arcadia: Kyllenion']
# ['Congupna, Victoria', 'County of Moira', 'List of government schools in Victoria, Australia', 'Congupna Football Club', 'Congupna railway station', 'Murray Football League', 'Electoral district of Shepparton', 'City of Greater Shepparton', 'Shepparton railway line', 'Shire of Shepparton']
# ['Dookie, Victoria', 'Dookie (disambiguation)', 'County of Moira', 'Peter John Ryan', 'Dookie United Football Club', 'Picola & District Football League', 'University of Melbourne', 'Major Plains, Victoria', 'Katamatite railway line', 'Yabba South']
# ['Grahamvale, Victoria', 'City of Greater Shepparton', 'Shepparton', 'City of Shepparton', 'Shire of Shepparton', 'Goulburn Valley Highway', 'Richard Pratt (Australian businessman)', 'List of localities in Victoria', 'List of road routes in Victoria (numeric)', 'William James (soldier)']
# ['Allendale, Victoria', 'Allendale', 'Allandale', 'Max Spittle', 'Frank McDonald (footballer)', 'Argyll Road, Edmonton', 'List of closed railway stations in Victoria', 'Shire of Hepburn', 'Jim Burt (American football)', 'Electoral district of Clunes and Allandale']
# ['Blampied, Victoria', 'Edmund Blampied', 'Vickers Viscount', 'Shire of Creswick', 'David Griffiths (co-operative economist)', 'Royal Society of British Artists', 'Wendouree railway station', 'List of members of the judiciary of Jersey', 'Jersey pound', 'Lambeth School of Art']
# ['Bullarto, Victoria', 'Bullarto railway station', 'Daylesford Spa Country Railway', 'County of Talbot, Victoria', 'Shire of Daylesford and Glenlyon', 'Shire of Moorabool', 'Blackwood, Victoria', 'Daylesford, Victoria', 'Musk railway station', 'Bendigo railway line']
# ['Clunes, Victoria', 'Clunes', '1851 in Australia', 'John Longstaff', 'Shire of Talbot and Clunes', '1873 in Australia', 'Australian gold rushes', 'John Burrows (politician)', 'Stafford Bird', 'Alexander Jobson']
# ['Antwerp, Victoria', 'Antwerp (disambiguation)', 'Ebenezer Mission', 'Antwerp Open', 'List of Second World War Victoria Cross recipients', 'Olympic symbols', 'Shire of Dimboola', 'Simon Colosimo', 'Erasmus de Bie', 'R. Cappellen F.C.']
# ['Dimboola', 'Rex Ingamells', 'Dimboola Football Club', 'Dimboola (film)', 'Larry Watson (footballer)', 'Shire of Dimboola', 'Dimboola Memorial Secondary College', 'Felix Reader', 'Wilfred Mibus', 'Borung Highway']
# ['Jeparit', 'Scottish Australians', 'Stawell Gift', 'James Menzies (Australian politician)', 'Robert Menzies', 'Mallee Football League (Victoria)', 'Electoral district of Lowan', 'Lake Hindmarsh', 'Shire of Hindmarsh', 'Wimmera River']
# ['Netherby, Victoria', 'Netherby', 'Horsham & District Football League', 'William Dalby', 'Electoral district of Waite', 'Shire of Lowan', 'Grade II* listed buildings in the City of Carlisle', 'Big Desert Wilderness Park', 'List of former Australian rules football competitions in Victoria', '1866 in Australia']
# ['Altona North, Victoria', 'Cherry Lake (Victoria)', 'Altona, Victoria', 'Altona', 'Altona Meadows, Victoria', 'City of Altona', 'Altona Gate Shopping Centre', 'Altona City SC', 'Altona Treatment Plant', "Mount St. Joseph Girls' College"]
# ['Newport, Victoria', 'Victoria Recreation Ground', 'Andrew Barlow', 'Newport', 'Greenwich Bay', 'Wentworth (TV series)', 'Newport Power Station', 'Charlie Page', 'Victoria', 'Dübs and Company']
# ['Seabrook, Victoria', 'Seabrook', 'The Goodsyard', 'Claude L. Harrison', 'Seabrook and Fildes', 'Electoral district of Altona', 'Folkestone, Hythe and Sandgate Tramways', '2009 Victoria Cup', 'Northern Thunder RLFC', 'Koala']
# ['Spotswood, Victoria', 'Spotswood', 'Harvie Krumpet', 'Spottiswoode', 'Bellarine Secondary College', 'Lakers Siding railway station', 'List of films shot in Melbourne', 'List of disasters in Australia by death toll', 'List of places named after people', '1977 Silver Jubilee and Birthday Honours']
# ['Brimpaen', 'Rural City of Horsham', 'Mount Talbot', 'List of localities in Victoria', 'List of Country Fire Authority brigades']
# ['Dadswells Bridge, Victoria', 'Koala', 'Rural City of Horsham', 'Shire of Wimmera', 'Grampians National Park', 'List of localities in Victoria', 'Shrine of Remembrance', '1928 Okeechobee hurricane', "Australia's big things", '2009–10 Australian bushfire season']
# ['Dooen, Victoria', 'Dry port', 'Henty Highway', 'Rural City of Horsham', 'Shire of Wimmera', 'Horsham, Victoria', 'County of Borung', 'HMAS Cerberus', 'List of localities in Victoria', 'Tachylite in Victorian archaeological sites']
# ['Haven, Victoria', 'Princess Victoria of Hesse and by Rhine', 'Haven', 'Boston, Lincolnshire', 'Louis IV, Grand Duke of Hesse', 'Sarah Morris', 'Milford Haven', 'Prince Louis of Battenberg', 'Safe-haven law', 'Haven (Star Trek: The Next Generation)']
# ['Bulla, Victoria', 'Electoral district of Bulla', 'Richard Brodie (cricketer)', 'Bulla', 'Mount Bulla Bulla', 'Shire of Bulla', 'Alister Clark Memorial Rose Garden', 'Rose garden', 'William Kelly (cricketer, born 1875)', 'Cairnlea FC']
# ['Campbellfield, Victoria', 'Broadmeadows Assembly', 'James Gibb (Australian politician)', 'Ford Fairlane (Australia)', 'Ford Fairmont (Australia)', 'Ford Falcon (BA)', 'Ford Cortina', 'Ford Falcon (ED)', 'Ford Falcon (BF)', '1957 Ford']
# ['Somerton, Victoria', 'N class', 'Queensland Railways 3300/3400 class', 'Somerton (disambiguation)', 'Dry port', 'Somerton', 'Somerton, Norfolk', 'Somerton, Newport', 'Somerton, Oxfordshire', 'Cowes']
# ['Coolaroo, Victoria', 'List of paper mills', 'Coolaroo railway station', 'Division of Calwell', 'Pascoe Vale Road, Melbourne', 'Dallas, Victoria', 'Electoral district of Broadmeadows', 'Meadow Heights, Victoria', 'Somerton, Victoria', 'Campbellfield, Victoria']
# ['Allans Flat, Victoria', 'Brian Grieve', 'Shire of Yackandandah', 'Kiewa Valley Highway', 'Genoa River', 'List of localities in Victoria', 'Dederang-Mt Beauty Football Club', 'Victoria Skating Rink', 'Rail transport in Victoria', 'Herne Hill railway station']
# ['Barnawartha, Victoria', 'County of Bogong', 'List of towns and cities in Australia by year of settlement', 'Hume Highway', 'Barnawartha railway station', 'Tallangatta & District Football League', 'Shire of Chiltern', 'Electoral district of Benambra', 'Indigo Valley, Victoria', 'List of closed railway stations in Victoria']
# ['Beechworth', 'Electoral district of Bogong', 'Electoral district of Ovens', 'Beechworth Correctional Centre', 'Beechworth Football Club', 'HM Prison Beechworth', 'Emma George', 'Ovens and Murray Advertiser', 'Richard Keane', 'Giaconda Winery']
# ['Chiltern, Victoria', 'Chiltern Football Club', 'Chiltern', 'Shire of Chiltern', 'County of Bogong', 'Mary Gaunt', 'Robert Cook (Australian politician)', 'William Poy', 'Ride a Wild Pony', 'Turquoise parrot']
# ['Chelsea, Victoria', 'Chelsea Clinton', 'Chelsea Heights, Victoria', 'Cameron Percy', 'Mordialloc-Cheltenham Community Hospital', 'Chelsea', 'Federal Football League', 'City of Chelsea', 'London Buses route 44', 'Michael Taylor (Australian cricketer)']
# ['Highett, Victoria', 'Federal Football League', 'The Cage (radio show)', 'Roundabout', 'Fred Turnbull (Australian footballer)', '1979 Birthday Honours', '1964 Birthday Honours', 'Highett railway station', 'William Highett', 'Highett Football Club']
# ['Edithvale, Victoria', 'Boatshed', 'Melbourne Sandbelt', 'Stawell Gift', 'List of baseball teams in Australia', 'List of cycling tracks and velodromes', 'Edithvale-Seaford Wetlands', 'Edithvale railway station', 'Electoral district of Carrum', 'Mornington Peninsula Nepean Football League']
# ['Mentone, Victoria', 'Dylan Shiel', 'Electoral district of Mentone', 'Brad Hodge', 'Mentone', "Leo O'Brien", 'Federal Football League', 'Eddie Perfect', 'Rex Hunt', 'Kilbreda College']
# ['Rowville, Victoria', 'Rowville Secondary College', 'Rowville Football Club', '3MP', 'Electoral district of Rowville', 'Eastern Football League (Australia)', 'Ravi Ratnayeke', 'Les Holden', 'Marty Johnstone', '2012 Rowville Rail Study']
# ['Scoresby, Victoria', 'Scoresby Football Club', 'Electoral district of Scoresby', 'County of Mornington', 'Melbourne Steam Traction Engine Club', 'Nintendo Australia', 'Scoresby', 'Wal Williams', 'Eastern Football League (Australia)', 'Gordon Hocking']
# ['Bayswater, Victoria', 'Bayswater North, Victoria', 'Bayswater Football Club', 'Torus Games', 'Fred Haigh Dam', 'Bayswater (disambiguation)', 'Electoral district of Bayswater', "Canada men's national softball team", 'Mackenzie River (Queensland)', 'Balonne River']
# ['Upper Ferntree Gully, Victoria', 'Ferntree Gully, Victoria', 'Dick Clay', 'Justin Kane', 'Wale Omotoso', 'Eastern Football League (Australia)', 'Anne Eckstein', 'Brendan Joseland', 'Electoral district of Ferntree Gully', 'Vic Cumberland']
# ['Boolarra, Victoria', 'Boolarra virus', 'List of earthquakes in Australia', 'Jack Furniss', 'Grand Ridge Rail Trail', 'Boolarra railway station', 'Mirboo North railway line', 'Mid Gippsland Football League', 'Morwell River', 'City of Morwell']
# ['Callignee, Victoria', 'County of Buln Buln', 'List of Grand Designs Australia episodes', 'Latrobe City', 'Shire of Traralgon', 'Traralgon Record', 'Traralgon Journal', 'List of localities in Victoria', 'Black Saturday bushfires', 'Hyland Highway']
# ['Churchill Island', 'Churchill, Victoria', 'Hazelwood North, Victoria', 'Borya', 'Hazelwood, Victoria', 'Hazelwood', 'Dale Foster', 'Churchill (disambiguation)', 'List of massacres in Australia', 'Kamal Siddiqi']
# ['Glengarry, Victoria', 'Veuve Clicquot', 'Glengarry (disambiguation)', 'Laroche Wines', 'Stormont, Dundas and Glengarry Highlanders', 'Glengarry railway station', 'Ontario Highway 43', 'Transit Eastern Ontario', 'North Gippsland Football League', 'Gippsland Plains Rail Trail']
# ['Arnold, Victoria', 'Arnold', 'Vigilante Force', 'William Herbert Higginbottom', 'Bergische Kräher', 'Arnold Loosemore', 'Berkeley Square (TV series)', '1960 New Year Honours', 'List of biographical films', 'Arnold Schwarzenegger']
# ['Bealiba', 'County of Gladstone', 'Natte Yallock', 'Lexton Plains Football League', 'Maryborough Castlemaine District Football League', 'Electoral district of Ripon', 'Shire of Bet Bet', 'Shire of Central Goldfields', 'Coliban Water', 'John Pennington (politician)']
# ['Boort', 'Wemba-Wemba', 'Tom Paul', 'Boort railway station', 'County of Tatchera', 'Boort Secondary College', 'Peter Walsh (Victorian politician)', 'Meat pie (Australia and New Zealand)', 'Myra Morris', 'Hank Nelson']
# ['Bridgewater On Loddon, Victoria', 'Loddon', 'Bridgewater', 'Alan Cordner', 'List of Australian military personnel killed at Anzac Cove on 25 April 1915', 'Loddon River', 'Loddon Valley Football League', 'Loddon Valley Highway', 'Electoral district of Ripon', 'County of Bendigo']
# ['Ashbourne, Victoria', 'Ashbourne', '1883–84 Stoke F.C. season', 'Thomas Gordon William Ashbourne', 'Ashbourne, County Meath', 'UCC GAA', 'Shire of Newham and Woodend', 'North Staffordshire Railway', 'Campaspe River', 'Woodend North, Victoria']
# ['Baynton, Victoria', 'County of Dalhousie', 'Baynton', 'The Wrong Mans', 'Horrible Histories (2009 TV series)', 'Pastoria East, Victoria', 'Shire of Kyneton', 'Coulston', 'List of wind farms in Victoria', 'Portarlington, Victoria']
# ['Bolinda, Victoria', 'Kerrie, Victoria', 'Lancefield railway line', 'Clarkefield, Victoria', 'Monegeetta, Victoria', 'Riddells Creek', 'Sunbury, Victoria', 'Tom Reynolds (Australian politician)', 'Clarkefield railway station', 'Obernewtyn (novel)']
# ['Bullengarook, Victoria', 'Gisborne, Victoria', 'The Old River', 'Macedon, Victoria', 'Campaspe River', 'Shire of Gisborne', 'Gisborne South, Victoria', 'Toolern Vale, Victoria', 'County of Bourke, Victoria', 'Jackson Creek (Victoria)']
# ['Ringwood North, Victoria', 'Norwood', 'Parkwood', 'PSC', 'Parkwood Secondary College', 'Ringwood (disambiguation)', 'The Biggest Loser Australia (season 2)', 'Electoral district of Ringwood (Victoria)', 'Ringwood, Victoria', 'City of Ringwood']
# ['Warrandyte South, Victoria', 'North Warrandyte, Victoria', 'Warrandyte, Victoria', 'The Island, Thompson Bend, Warrandyte', 'Cameron Donald', 'County of Evelyn, Victoria', 'Electoral district of Warrandyte', 'Pound Bend Tunnel', 'Warrandyte High School', 'Louis John Michel']
# ['Nunawading, Victoria', 'Nunawading Spectres', 'Stuart Blackler', 'City of Whitehorse Pipe Band', 'Nunawading Christian College', 'The Go!! Show', 'Electoral district of Nunawading', 'Australian Venture', 'City of Nunawading', 'National Premier Leagues Victoria 2']
# ['Doncaster, Victoria', 'Doncaster East, Victoria', 'Kingswood College', 'John Blakey', 'Eastern Football League (Australia)', 'Doncaster East Football Club', 'Electoral district of Doncaster', 'Doncaster Baseball Club', 'Ron Gaunt', 'Kingswood College Doncaster']
# ['Ancona, Victoria', 'Ancona (disambiguation)', 'The Big Impression', 'Palatias and Laurentia', 'Shire of Mansfield (former)', 'List of QI episodes', 'The Museum of Curiosity', 'Santa Vittoria in Matenano', 'Pesaro', 'Alistair McGowan']
# ['Bonnie Doon, Victoria', 'Bonnie Doon, Edmonton', 'Bonnie Doon railway station', 'Bonnie Doon', 'Rail trail', 'Benalla & District Football League', 'Great Victorian Rail Trail', 'Merton, Victoria', 'Ovens & King Football League', 'Mansfield railway line']
# ['Gaffneys Creek, Victoria', 'Paul Jones (Australian politician)', 'Tunnel Bend diversion tunnel', 'Mark Fagan', 'J. J. Kenneally', 'Kevington', 'Shire of Mansfield (former)', 'List of localities in Victoria', 'A1 Mine Settlement', 'Coburg, Victoria']
# ['Jamieson, Victoria', 'Jamieson', 'Jamieson River', 'County of Wonnangatta', 'Newbery Medal', 'Kenneth G. Ross', 'William Grene Power', 'David Jamieson (VC)', 'Penny Jamieson', 'David Jamieson']
# ['Maidstone, Victoria', 'Maidstone (disambiguation)', 'Croatian Australians', 'Jim Jackson (Australian rules footballer)', 'A Fortunate Life', 'Croat Muslims', '1983–84 Alliance Premier League', '1982–83 Alliance Premier League', '1987–88 Football Conference', '1986–87 Football Conference']
# ['West Footscray, Victoria', 'City of Footscray', 'Don Nardella', 'Footscray, Victoria', 'Jack Aziz', 'Colin Miller (cricketer)', 'Russell Gilbert', 'Electoral district of Footscray', 'Ian Robertson (Australian rules footballer)', 'Damien Fotiou']
# ['Seddon, Victoria', 'Seddon', 'Laurie Sandilands', 'Tony Leonard', 'List of places named after people', "St Padarn's Church, Llanbadarn Fawr", 'Richard Seddon', 'Tom Seddon', 'Gareth Seddon', 'Seddon railway station']
# ['Braybrook, Victoria', 'Sunshine, Victoria', 'Skinner Reserve', 'Hi-Lite Park', 'Braybrook College', 'Australian rules football playing field', 'Teisutis Zikaras', 'Masters Home Improvement', 'Caroline Chisholm Catholic College, Melbourne', 'Chisholm School']
# ['Electoral results for the district of Croydon (Victoria)', 'Electoral district of Croydon (Victoria)', 'Croydon North, Victoria', 'Croydon South, Victoria', 'Croydon, Victoria', 'Croydon City Arrows', 'Croydon Hills, Victoria', 'Croydon Secondary College', 'South Croydon Football Club', 'Luther College']
# ['Heathmont, Victoria', 'Heathmont College', 'Heathmont Baseball Club', 'Eastern Football League (Australia)', 'William Ellis Green', 'Don Talbot (author)', 'Heathmont Bowls Club', '1966 Birthday Honours', '1977 Silver Jubilee and Birthday Honours', 'Heathmont railway station']
# ['Warranwood, Victoria', 'City of Maroondah', 'Electoral district of Warrandyte', 'Division of Menzies', 'City of Croydon', 'Warrandyte South, Victoria', 'City of Doncaster & Templestowe', 'Ringwood North, Victoria', 'Croydon Hills, Victoria', 'Warrandyte, Victoria']
# ['Kilsyth South, Victoria', 'Kilsyth, Victoria', 'Kilsyth Wanderers F.C.', 'Electoral district of Kilsyth', 'Electoral results for the district of Kilsyth', 'Electoral district of Mooroolbark', 'Caladenia sp. Kilsyth South', 'Eastern Football League (Australia)', 'Clare Nott', 'Electoral district of Goulburn (Victoria)']
# ['Carlton, Victoria', 'Carlton North, Victoria', 'Sharlene Heywood', 'Lardie Tulloch', 'Valerie Farrell', 'Janette Tredrea', 'Australasian Institute of Mining and Metallurgy', 'Medley Hall', 'Ken Inglis', 'Ernie McCormick']
# ['Docklands, Victoria', 'Harbour Town', 'Docklands', 'Melbourne Mustangs', 'AFL NSW/ACT', 'Mirvac', '1924 Brownlow Medal', 'Australian Ice Hockey League', 'Victoria Harbour (disambiguation)', 'Docklands Studios Melbourne']
# ['Kensington, Victoria', 'Kensington Town Hall', 'Edric Bickford', 'Lucas Browne', 'The Reject Shop', 'Victoria Park, Western Australia', 'Kensington, Western Australia', 'Sloane Square tube station', 'Kevin Dynon', 'East Victoria Park, Western Australia']
# ['Flemington, Victoria', 'Blake Caparello', 'Omari Kimweri', 'Hugh Glass (pastoralist)', 'Telmo Languiller', 'Flemington', 'Electoral district of Flemington', 'Electoral district of Essendon and Flemington', 'Flemington Racecourse', 'Mount Alexander College']
# ['Rockbank, Victoria', 'Rockbank railway station', 'Riddell District Football League', 'Electoral district of Melton', 'Western Freeway (Victoria)', 'Ballarat V/Line rail service', 'Plumpton, Victoria', 'Mount Cottrell, Victoria', 'Melton railway line', 'Toolern Vale, Victoria']
# ['Exford, Victoria', 'Exford', 'Howard Spensley', 'Toolern Creek', 'Melton South, Victoria', 'Eynesbury, Victoria', 'Parwan, Victoria', 'List of closed railway stations in Victoria', 'Western Freeway (Victoria)', 'Werribee River']
# ['Brookfield, Victoria', 'Brookfield railway station, Victoria', 'Brookfield', 'Brookfield railway station', 'London Borough of Camden', 'Electoral district of Melton', 'William Henry Brookfield', 'Parwan, Victoria', 'Exford, Victoria', 'Preston City Council election, 2016']
# ['Melton, Victoria', 'Melton West, Victoria', 'Melton South, Victoria', 'Melton, Victoria (suburb)', 'Melton', 'Toolern Vale, Victoria', 'Melton Broncos', '979fm', 'Melton Airfield', 'Melton Christian College']
# ['Big Desert Wilderness Park', 'Black Rock Desert', 'Joshua Tree National Park', 'Avon Wilderness Park', 'Mojave Desert', 'Protected areas of Victoria', 'Colorado Plateau', 'Low Desert', 'Great Basin Desert', 'Antarctica']
# ['Birdwoodton, Victoria', 'List of places named after William Birdwood', 'Cabarita, Victoria', 'Koorlong, Victoria', 'Merbein South', 'Merbein', 'Shire of Mildura', 'Mildura', 'List of localities in Victoria']
# ['Boinka, Victoria', 'Tutye, Victoria', 'Linga, Victoria', 'County of Weeah', 'Big Desert Wilderness Park', 'Murray-Sunset National Park', 'Mallee Highway', 'Nowingi, Victoria', 'List of localities in Victoria', 'Myoporum brevipes']
# ['Cabarita, Victoria', 'Cabarita', 'Concord, New South Wales', 'Birdwoodton, Victoria', 'Division of Lowe', 'Division of Reid', 'Shire of Mildura', 'Parramatta River', 'Raw FM (Australian radio network)', 'Group 18 Rugby League']
# ['Beveridge, Victoria', 'Beveridge Island (Victoria)', 'Mount Fraser (Australia)', 'Beveridge railway station', 'Hume and Hovell expedition', 'Beveridge Island', "Charles O'Hea", 'Beveridge', 'Kate Kelly (outlaw)', 'Dan Kelly (bushranger)']
# ['Broadford, Victoria', 'Alan Ezard', 'Albert Zwar', 'Shire of Broadford', 'Broadford', 'Mervyn Lee', 'Calibre Sports', 'County of Dalhousie', 'Henry Zwar', 'Broadford Secondary College']
# ['Clonbinane, Victoria', 'Flowerdale, Victoria', 'Kinglake West, Victoria', 'Shire of Broadford', 'Broadford, Victoria', 'Kilmore East, Victoria', 'Strath Creek, Victoria', 'Whittlesea, Victoria', 'Mount Disappointment (Australia)', 'Wandong']
# ['Kilmore, Victoria', 'Kilmore East, Victoria', 'Assumption College, Kilmore', 'Jon Hassall', 'Assumption College (disambiguation)', 'Blake Shinn', 'Assumption', 'Kilmore International School', 'Shire of Kilmore', 'OKR FM']
# ['Almonds, Victoria', 'Almond', 'Boweya North', 'Pelluebla', 'Wilby, Victoria', 'Nangiloc, Victoria', 'Colignan, Victoria', 'Timbercorp', 'Carina, Victoria', 'Supreme Court of Victoria']
# ['Barmah', 'Joseph Waldo Rice', 'County of Moira', 'Barmah National Park', 'List of Edmund Rice (1638) descendants', 'Johnny Jarrett', 'Barmah Forest virus', 'Picola West', 'Electoral district of Shepparton', 'Nathalia, Victoria']
# ['Bathumi', 'Bundalong, Victoria', 'Shire of Yarrawonga', 'Yarrawonga, Victoria', 'List of localities in Victoria']
# ['Bearii, Victoria', 'Strathmerton', 'Yalca', 'List of localities in Victoria']
# ['Clayton South, Victoria', 'Clayton, Victoria', 'Ernest Bromley (cricketer)', 'Waverley Oakleigh Panthers', 'Alec Potts', 'Electoral district of Clayton', 'Monash Institute of Medical Research', 'Clayton', 'Westall UFO', 'Nissan Pintara']
# ['Electoral district of Mulgrave (Victoria)', 'Electoral results for the district of Mulgrave (Victoria)', 'City of Waverley', 'Mulgrave, Victoria', 'Waverley Park', 'Mazenod College, Victoria', 'Kingfisher International', 'Bulla Dairy Foods', 'Mulgrave', 'Electoral district of Mulgrave']
# ['Oakleigh East, Victoria', 'Oakleigh South, Victoria', 'Oakleigh Chargers', 'Oakleigh, Victoria', 'Shaun Leane', 'Oakleigh Cannons FC', "Sacred Heart Girls' School, Oakleigh", 'Oakleigh', 'James Hamlyn Willis', 'Australian Masters']
# ['Huntingdale, Victoria', 'Huntingdale', 'Huntingdale railway station', 'Oakleigh South, Victoria', 'Huntingdale Golf Club', 'Australian Masters', 'Chadstone, Victoria', 'North Road Trail', 'Oakleigh East, Victoria', 'Division of Chisholm']
# ...
# ['Toorak, Victoria', 'Toorak', 'Lisa Thompson (set decorator)', 'Electoral district of Toorak', 'Jack Saunders (Australian cricketer)', 'Charlie McLeod', 'Nora Clench', 'Olive Blanche Davies', "St Kevin's College, Melbourne", 'Tup Scott']
# ['Malvern, Victoria', 'Malvern East, Victoria', 'Keith Rigg', 'Piccadilly Cinema, Birmingham', 'Charles Godby', 'De La Salle College', 'Jack Laver', 'Malvern', 'Electoral district of Malvern', 'Catherine Arlove']
# ['Kooyong, Victoria', 'Malvern City FC', 'Petro Georgiou', 'Kooyong by-election, 1994', '1930 in Australia', 'Division of Kooyong', 'Kooyong', 'Outside broadcasting', 'Kooyong Stadium', 'Victorian Amateur Football Association']
# ['Prahran, Victoria', 'Burnet Institute', '100 Best Australian Albums', 'Jack Edwards (cricketer)', "Prahran Mechanics' Institute", 'Blair Wark', '1001 Songs', 'Australian non-residential architectural styles', 'The Palms National Park', 'City of Prahran']
# ['Avenel, Victoria', 'County of Moira', 'Avenel', 'Ian Shelton (footballer)', 'Colin McKenzie (cricketer)', 'Bill Shelton (footballer, born 1936)', 'John Tonkin (New South Wales politician)', 'Albert Tonkin', 'Jack Shelton', 'Whitemore, Tasmania']
# ['Euroa', 'Jamie Elliott (footballer born 1992)', 'Electoral district of Shepparton and Euroa', 'Euroa Gazette', 'Electoral district of Euroa', 'Kingston Rule', 'Shire of Euroa', 'Drop zone', 'Hume and Hovell expedition', '1878 in Australia']
# ['Longwood, Victoria', 'Longwood', 'County of Moira', 'Mount Teneriffe', 'Charles Ryan (surgeon)', 'List of Australian botanical illustrators', 'Frederick Tubb', 'Bushfires in Victoria', 'Ellis Rowan', 'List of disasters in Australia by death toll']
# ['Mangalore, Victoria', 'Mangalore Airport (Victoria)', 'County of Anglesey, Victoria', 'Mangalore (disambiguation)', 'List of airports by ICAO code: Y', 'Main Southern railway line, New South Wales', 'Australia–India relations', 'Australian National Airways', 'Camp Cable', 'SDM Law College']
# ['Aireys Inlet', 'Rhys Lee', 'John Airey', 'Alpha Scorpio', 'Split Point Lighthouse', 'Airey', 'Round the Twist', 'Orders of magnitude (length)', 'Ash Wednesday bushfires', 'Stars and planetary systems in fiction']
# ['Anglesea, Victoria', 'Bellbrae, Victoria', 'Anglesea', 'Lord Somers Camp', 'Geshe Sonam Thargye', 'Australian Venture', 'Tegan Philip', 'Anglesea Power Station', 'New Holland mouse', 'Bellarine Football League']
# ['Bellbrae, Victoria', 'Brooke Davis (writer)', 'Jan Juc, Victoria', 'Bells Beach, Victoria', 'Electoral district of South Barwon', 'Shire of Barrabool', 'Torquay, Victoria', 'Anglesea, Victoria', 'Paraparap, Victoria', 'Surf Coast Shire']
# ['Deans Marsh, Victoria', 'Forrest railway line', 'Winchelsea, Victoria', 'List of former Australian rules football competitions in Victoria', 'George Davys', 'Shire of Winchelsea', 'Anglican Diocese of Ballarat', 'Pennyroyal, Victoria', 'Forrest, Victoria', 'Boonah, Victoria']
# ['Annuello, Victoria', 'County of Karkarooc', 'Wandown, Victoria', 'Winnambool, Victoria', 'Bolton, Victoria', 'Bannerton, Victoria', 'Murray-Sunset, Hattah and Annuello Important Bird Area', 'Wemen, Victoria', 'Kulwin, Victoria', 'Lake Powell, Victoria']
# ['Bannerton, Victoria', 'Tol Tol, Victoria', 'Robinvale Irrigation District Section E', 'Lake Powell, Victoria', 'Wemen, Victoria', 'Happy Valley, Victoria', 'Annuello, Victoria', 'Shire of Swan Hill', 'Robinvale railway station', 'Robinvale railway line']
# ['Beverford, Victoria', 'Woorinen North, Victoria', 'Woorinen, Victoria', 'Vinifera, Victoria', 'Speewa, Victoria', 'Tyntynder, Victoria', 'Tyntynder South, Victoria', 'Shire of Swan Hill', 'Woorinen South, Victoria', 'List of localities in Victoria']
# ['Bolton, Victoria', "Queen's Park, Bolton", 'Victoria Hall', 'Bolton (disambiguation)', 'Victoria foundry', 'Colne railway station', 'Blackburn railway station', 'List of mills in Bolton', 'Members of the Australian Senate, 1917–1920', 'Members of the Australian Senate, 1920–1923']
# ['Bellbridge, Victoria', 'Bethanga Bridge', 'Shire of Tallangatta', 'Bethanga, Victoria', 'Hoppers Crossing, Victoria', 'Hume Dam', 'List of localities in Victoria', 'Nights: Journey of Dreams', 'List of crossings of the Murray River', 'List of government schools in Victoria, Australia']
# ['Bethanga, Victoria', 'Wodonga Saints Football Club', 'Edward Ford (physician)', 'Bethanga Bridge', 'Bellbridge, Victoria', 'Hume Football League', 'Tallangatta & District Football League', 'Shire of Tallangatta', 'Stanley Goldsworthy', 'Bert Mills']
# ['Corryong', 'Corinne Grant', 'Corryong Courier', 'Federal Football Netball Club', 'Upper Murray Football Netball League', 'Tom Mitchell (Australian politician)', 'Corryong Airport', 'County of Benambra', 'List of airports by ICAO code: Y', 'Corryong Football Netball Club']
# ['Cudgewa, Victoria', 'Cudgewa railway station', 'County of Benambra', 'Bob Chitty', 'Cudgewa Football Netball Club', 'Upper Murray Football Netball League', 'List of Australian rules football clubs by date of establishment', 'Cudgewa railway line', 'High Country Rail Trail', 'Huon railway station']
# ['Cheshunt, Victoria', 'Cheshunt', 'List of monastic houses in Hertfordshire', 'Cheshunt Park', "St Mary's Church of England High School", 'London Victoria station', 'John Dalton (musician)', 'Waltham Cross', 'Herts Senior Cup', 'King River (Victoria)']
# ['Eldorado, Victoria', 'Thomas Heron', 'El Dorado (disambiguation)', 'Thunder Bay/Eldorado Aerodrome', 'Shire of Wangaratta (Victoria)', 'Rural City of Wangaratta', 'Ovens & King Football League', 'Wangaratta Rovers Football Club', 'Wangaratta Football Club', 'Stanley, Victoria']
# ['Everton, Victoria', 'Everton', 'County of Bogong', 'FA Cup semi-finals', 'Highways in Australia', 'Goodison Park', "St George's Church, Everton", 'Anfield', 'Everton railway station', 'Liverpool Everton by-election, 1892']
# ['Glenrowan, Victoria', 'Matthew Gibney', '1880 in Australia', 'Jason Maroney', 'Adam Ford', '1880', 'Aboriginal tracker', 'John William Cotter', 'Dan Kelly (bushranger)', 'Treasury Wine Estates']
# ['Allansford, Victoria', 'Warrnambool Cheese and Butter', 'Edward Both', 'Colin Watson (footballer)', 'Great Ocean Road', 'Princes Highway', 'Percy Taylor', 'Jack Bristow (footballer)', 'Jim Willis (footballer)', 'Frank Allan']
# ['Bushfield, Victoria', 'Woodford, Victoria', 'Merri River', 'North Warrnambool Football Club', 'Clay Lane', 'Warrnambool District Football League', 'City of Warrnambool', 'Warrnambool', 'Ken Collicoat', 'Ottawa municipal election, 1978']
# ['Dennington, Victoria', 'Dennington', 'Condensed milk', 'Shane Howard', 'Fonterra', 'Warrnambool railway station', 'Warrnambool District Football League', 'Jack Dennington', 'Warrnambool railway line', 'George Gibbs (Australian politician)']
# ['Warrnambool', 'Warrnambool Airport', 'Peter F. Meurs', 'City of Warrnambool', 'Cyril Primmer', 'Bushfield, Victoria', 'Edward Russell (Australian politician)', 'HMAS Warrnambool (J202)', 'HMAS Warrnambool (FCPB 204)', "King's College, Warrnambool"]
# ['Alberton, Victoria', 'Alberton West, Victoria', 'Shire of Alberton', 'Electoral district of Alberton', 'Alberton', 'County of Buln Buln', 'James Davis', 'Walter Nairn', 'Victorian Railways wooden bogie passenger carriages', 'Robert Wilkinson (footballer)']
# ['Alberton West, Victoria', 'County of Buln Buln', 'List of Australian rules football clubs in Australia', 'Shire of Alberton', 'Alberton, Queensland', 'Electoral district of Alberton', 'Alberton, South Australia', 'Alberton Football Netball League', 'Shire of Rosedale', 'Electoral district of Goulburn (Victoria)']
# ['Boisdale, Victoria', 'Boisdale', 'Valencia Creek, Victoria', 'Newry, Victoria', 'North Gippsland Football League', 'Riviera Football League', 'Cape Breton North and Victoria', 'East Gippsland Football League', 'Briagolong, Victoria', 'Briagolong railway line']
# ['Briagolong, Victoria', 'County of Tanjil', 'Briagolong railway line', 'Boisdale, Victoria', 'Bushy Park, Victoria', 'North Gippsland Football League', 'Riviera Football League', 'Turton River', 'East Gippsland Football League', 'Thorpdale railway line']
# ['Apsley, Victoria', 'Apsley', 'Bill Lyon', 'Fanny Hines', 'Joseph Botterill', 'Michael Kauffmann', 'Dipodium campanulatum', 'Daniel Cudmore (businessman)', 'Apsley House', 'Edenhope, Victoria']
# ['Edenhope, Victoria', 'Emma Kealy', 'Phil Carman', 'Ted Allsopp', 'Robert Hankinson', 'William Hutchison (pastoralist)', 'Leslie Duncan', 'Lake Wallace', 'Richard Charles Guthridge', 'Calectasia intermedia']
# ['Goroke, Victoria', 'Goroke P-12 College', 'Horsham & District Football League', 'Gymbowen, Victoria', 'Shire of West Wimmera', 'Minimay, Victoria', 'Harrie Wade', 'Shire of Kowree', 'Natimuk-Douglas Wetlands', '1943–44 Victorian bushfire season']
# ['Gymbowen, Victoria', 'Shire of West Wimmera', 'Shire of Kowree', 'Goroke, Victoria', 'County of Lowan', 'Goroke P-12 College', 'List of localities in Victoria', 'List of Country Fire Authority brigades']
# ['Electoral district of Mitcham (Victoria)', 'Mitcham, Victoria', 'Electoral results for the district of Mitcham (Victoria)', 'Electoral district of Mitcham (South Australia)', 'Andrew Moloney', 'Mullauna College', 'Mitcham (disambiguation)', 'Mitcham, Australia', 'Eastern Football League (Australia)', 'Electoral district of Mitcham']
# ['Blackburn South, Victoria', 'Blackburn, Victoria', 'Blackburn North, Victoria', 'Blackburn War Memorial', 'Myra Nicholson', 'Blackburn Football Club', 'Blackburn (disambiguation)', 'Laburnum, Victoria', 'Nunawading Football Club', 'Eastern Football League (Australia)']
# ['Box Hill North, Victoria', 'Box Hill, Victoria', 'Box Hill South, Victoria', 'Kingswood College', 'Paul Reiffel', 'Kingswood College (Box Hill)', 'Box Hill Senior Secondary College', 'Sonya Hartnett', 'Box Hill Town Hall', 'City of Box Hill']
# ['Vermont South, Victoria', 'Pop-culture tourism', 'Weeden', 'Tom Uglys Bridge', 'Wobbies World', 'Emmaus College, Melbourne', 'TRANSYT-7F', 'Paul Melville', '1978 New Year Honours', 'List of government schools in Victoria, Australia']
# ['Bundoora, Victoria', 'Bundoora Football Club', 'Patrick Veszpremi', 'City Football Academy (Melbourne)', 'Electoral district of Bundoora', 'Pakanic languages', 'Bolyu language', 'RMIT Building 220', 'La Trobe University', 'University Hill']
# ['Lalor, Victoria', 'Whittlesea Ranges FC', 'Lalor Football Club', 'Joanne Ryan (politician)', 'Peter Lalor Vocational College', 'Westgarthtown, Victoria', 'Division of Lalor', 'Peter Lalor', 'Garden city movement', 'Lalor']
# ['Epping, Victoria', 'Pacific Epping', 'Epping', 'Fawkner (disambiguation)', 'Epping Secondary College', 'Epping Stadium', '2009 Victorian Premier League', 'National Premier Leagues Victoria 2', 'The Northern Hospital, Epping', 'East West Bus Company']
# ['Mernda', 'Electoral district of Mernda', 'Mernda Dragons', 'Acacia College', 'J. J. Kenneally', 'Ivanhoe Grammar School', 'Division of Mernda', 'Mernda Football Club', 'Electoral results for the Division of Mernda', 'Electoral district of Bulla and Dalhousie']
# ['Bandiana, Victoria', 'Army Logistic Training Centre (Australia)', 'Wadsworth', 'Tenix Defence', 'Royal Australian Army Medical Corps', 'Wadsworth Barracks', 'Sydney Heads', 'Gaza Ridge Barracks', 'Australian Army Aviation', 'Amiens Gun']
# ['Bonegilla, Victoria', 'Finnish Australians', 'County of Bogong', 'Post-war immigration to Australia', 'Army Recruit Training Centre', 'Latchford Barracks', '2/40th Battalion (Australia)', 'Karl Kruszelnicki', '3rd Division (Australia)', 'Charles Ebden']
# ['Wodonga', 'Wodonga Football Club', 'Wodonga Storm', 'Albury Airport', 'Mitchell Secondary College', 'Scott Martin (athlete)', 'Andrew McDonald (cricketer)', 'Wodonga Middle Years College', 'Wodonga Senior Secondary College', "Patrick O'Brien (political scientist)"]
# ['Gateway Island, Victoria', 'Tower Gateway DLR station', 'Tourist gateway', 'Victoria (Australia)', 'Portland Airport (Victoria)', 'List of airports by ICAO code: Y', 'Ballina Byron Gateway Airport', 'Victoria & Alfred Waterfront', 'Victoria Park, Western Australia', 'Island Gardens DLR station']
# ['Laverton North, Victoria', 'Laverton, Victoria', 'No. 36 Squadron RAAF', 'Laverton Magpies Football Club', 'No. 37 Squadron RAAF', 'Jason Lees', 'Frank Lukis', 'Alan Charlesworth', 'Laverton', 'Laverton railway station, Melbourne']
# ['Tarneit, Victoria', 'Electoral district of Tarneit', 'Thomas Carr', 'Thomas Carr College', 'Wayde Twomey', 'List of government schools in Victoria, Australia', 'Electoral results for the district of Tarneit', 'Tarneit railway station', 'Electoral district of Werribee', 'Tim Pallas']
# ['Werribee South, Victoria', 'Werribee, Victoria', 'Galvin Park Secondary College', 'Werribee Mercy Hospital', 'Gordon Institute of TAFE', 'MacKillop Catholic Regional College', 'Ibrahim Balla', 'Werribee Bears', 'Adem Yze', 'Chirnside Park (stadium)']
# ['Williams Landing, Victoria', 'Richard Williams (RAAF officer)', 'Williams Landing railway station', 'Apollo 11', 'Moon landing conspiracy theories', 'Frank McNamara (VC)', 'Gallipoli Campaign', 'RAAF Williams', 'Victoria (crater)', 'Normandy landings']
# ['Abbotsford, Victoria', 'Abbotsford', 'Stomp Entertainment', 'Electoral district of Abbotsford', 'Abbotsford motorcycles', 'Thomas Cope (Australian politician)', 'Skipping Girl Vinegar', 'Sophia Mundi Steiner School', 'Abbotsford Primary School', 'Victoria Park']
# ['Cremorne, Victoria', 'Cremorne', 'Nylex Clock', 'Colorado Group Limited', 'Dark Horses (album)', "Borsari's Corner, Melbourne", 'Pelaco Sign', 'Skipping Girl Sign', 'Australian non-residential architectural styles', 'Dingo Flour sign']
# ['Electoral district of Fitzroy (Victoria)', 'Fitzroy North, Victoria', 'Fitzroy River (Victoria)', 'Spudbar', 'Fitzroy, Victoria', 'City of Fitzroy', '1858 in Australia', 'Trifekta', 'Black Dog Books (Australian publisher)', 'Ryan Sullivan']
# ['Collingwood, Victoria', 'Collingwood College, Victoria', 'City of Collingwood', 'Electoral district of Collingwood', 'Jim Sharp', 'Sidchrome', 'Australian Soil Classification', 'Collingwood', 'Turquoise parrot', 'Persoonia moscalii']
# ['Coldstream, Victoria', 'Domaine Chandon California', 'Coldstream railway station, Melbourne', 'Olinda Creek', 'Eastern Football League (Australia)', 'Coldstream Airport', 'Bronwyn Oliver', 'Melba Highway', 'Coldstream (disambiguation)', 'List of airports by ICAO code: Y']
# ['Cambarville, Victoria', 'The Big Culvert', 'Shire of Upper Yarra', 'Narbethong, Victoria', "Leadbeater's possum", 'Black Saturday bushfires', 'List of Melbourne suburbs', 'Eucalyptus regnans']
# ['Emerald, Victoria', 'South Melbourne, Victoria', 'Asterolasia asteriscophora', 'Joan Sydney', 'Arthur Coningham (cricketer)', 'Clematis, Victoria', 'Electoral district of Emerald Hill', 'Pitt Town, New South Wales', 'Emerald Hill', 'Nehemiah Guthridge']
# ['Belgrave South, Victoria', 'Belgrave, Victoria', 'Belgrave Heights, Victoria', 'Mater Christi College', 'Burwood Highway', 'Upwey, Dorset', 'Epacris impressa', 'Belgrave (Puffing Billy) railway station', 'Belgrave', 'Arthur Betts (cricketer)']
# ['Areegra, Victoria', 'Wilkur, Victoria', 'Eric Kent', 'Shire of Warracknabeal', 'County of Borung', 'List of localities in Victoria', 'List of Country Fire Authority brigades']
# ['Beulah, Victoria', 'Lance Collins', 'Beulah', 'County of Karkarooc', 'Reedy Dam, Victoria', 'Mallee Football League (Victoria)', '1959 Atlantic hurricane season', 'Sippie Wallace', 'Curyo, Victoria', 'Watchupga, Victoria']
# ['Brim, Victoria', 'Brim', 'List of reduplicated Australian place names', 'Kellalac, Victoria', 'Lah, Victoria', 'Coal scuttle bonnet', 'Wilkur, Victoria', 'County of Dundas, Victoria', 'Poke bonnet', 'Mushroom hat']
# ['Hopetoun, Victoria', 'Hopetoun Airport', 'Kel Glare', 'Laurence Schache', 'Hopetoun', 'List of airports by ICAO code: Y', 'Early 2009 southeastern Australia heat wave', 'List of airports by IATA code: H', 'Yarriambiack Creek', 'Graham Perkin']

# %% [markdown]
# ## Formatting and Exporting the results

# %%
#a.url, a.summary, img_url, img_fn, img_status, str(img_list)
suburbdf = pd.DataFrame(suburbdata,columns=['wiki.url','wiki.summary','img_url','img_fn','img_status','img_list'])
suburbdf = suburbdf.set_index(flatsuburb)
#suburbdf = suburbdf.reset_index()
#suburbdf['image']=suburbdf.apply(suburb_image, axis=1)

# %%
suburbdf[suburbdf['wiki.url']=='null']
# Out:
#             wiki.url wiki.summary img_url img_fn img_status img_list
# Taytoon         null         null    null   null       null     null
# Tamnick         null         null    null   null       null     null
# Gembrook        null         null    null   null       null     null
# Reservoir       null         null    null   null       null     null
# Karingal        null         null    null   null       null     null
# Jeparit         null         null    null   null       null     null
# Boort           null         null    null   null       null     null
# Croydon         null         null    null   null       null     null
# Wattle Glen     null         null    null   null       null     null

# %%
writer = pd.ExcelWriter('suburbs-v2.xlsx')
suburbdf.to_excel(writer,'Sheet1')
writer.save()

# %%
suburbdf
# Out:
#                   index                                            summary  \
# 0            Myrtleford  Myrtleford is a town in Victoria, Australia. I...
# 1                Bright  Bright (pronunciation [ˈbɹɑet̥]) is a town in ...
# 2            Porepunkah  Porepunkah is a town in northeast Victoria, Au...
# 3         Tawonga South                                               null
# 4                Ararat  Ararat is a city in south-west Victoria, Austr...
# 5               Moyston  Moyston is a town in the Western District regi...
# 6               Taytoon  Tatyoon is a town in the northern region of Vi...
# 7              Cathcart                                               null
# 8             Wendouree  Wendouree is a large suburb on the north weste...
# 9            Sebastopol  Sebastopol is a southern suburb on the rural-u...
# 10            Alfredton  Alfredton is a suburb of Ballarat, Victoria, A...
# 11     Ballarat Central  Ballarat Central (known as the Central Busines...
# 12               Rosana  Rosanna is a suburb of Melbourne, Victoria, Au...
# 13             Viewbank  Viewbank is a suburb of Melbourne, Victoria, A...
# 14   Heidelberg Heights  Heidelberg Heights is a suburb of Melbourne, V...
# 15            Yallambie  Yallambie is a suburb of Melbourne, Victoria, ...
# 16              Benalla  Benalla /bəˈnælə/ is a small city located on t...
# 17              Tamnick                                               null
# 18             Devenish  Devenish is a town in northern Victoria, Austr...
# 19            Goorambat  Goorambat /ˈɡʊərəmbæt/ is a town in northern V...
# 20            Aberfeldy  Aberfeldy is a small town in Victoria, Austral...
# 21              Athlone  Athlone is a small town in Victoria, Australia...
# 22            Buln Buln  Buln Buln is a small town in West Gippsland, a...
# 23               Darnum  Darnum is a small town in West Gippsland, Vict...
# 24             Brighton  Brighton is a beach-side suburb of Melbourne, ...
# 25          Sandringham  Sandringham is a beachside suburb of Melbourne...
# 26            Moorabbin  Moorabbin is a suburb in Melbourne, Victoria, ...
# 27           Mordialloc  Mordialloc, also known simply as Mordi, is a s...
# 28          Baddaginnie  Baddaginnie is a small town in Victoria, Austr...
# 29              Benalla  Benalla /bəˈnælə/ is a small city located on t...
# ..                  ...                                                ...
# 285              Goroke  Goroke (/ɡoʊrˈoʊk/ gur-OHK) is a town in the W...
# 286            Gymbowen  Gymbowen is a township in the Shire of West Wi...
# 287             Mitcham  Mitcham is a suburb of Melbourne, Victoria, Au...
# 288           Blackburn  Blackburn is a suburb of Melbourne, Victoria, ...
# 289            Box Hill  Box Hill is a suburb of Melbourne, Victoria, A...
# 290       Vermont South  Vermont South is a suburb of Melbourne, Victor...
# 291            Bundoora  Bundoora is a suburb of Melbourne, Victoria, A...
# 292               Lalor  Lalor is a suburb of Melbourne, Victoria, Aust...
# 293              Epping  Epping is a suburb of Melbourne, Victoria, Aus...
# 294              Mernda  Mernda is a suburb of Melbourne, Victoria, Aus...
# 295            Bandiana  Bandiana is a bounded rural locality of the Ci...
# 296           Bonegilla  Bonegilla is a bounded rural locality of the C...
# 297             Wodonga  Wodonga /wəˈdɒŋɡə/ is a city on the Victorian ...
# 298      Gateway Island  Gateway Island is an unpopulated suburb of the...
# 299            Laverton  Laverton is a suburb of Melbourne, Victoria, A...
# 300             Tarneit  Tarneit ( pronunciation (help·info)) is a rura...
# 301            Werribee  Werribee is a suburb of Melbourne, Victoria, A...
# 302    Williams Landing  Williams Landing is a suburb of Melbourne, Vic...
# 303          Abbotsford  Abbotsford is a suburb of Melbourne, Australia...
# 304            Cremorne  Cremorne is a small suburb in inner Melbourne,...
# 305             Fitzroy  Fitzroy is a suburb of Melbourne, Australia, 2...
# 306         Collingwood  Collingwood is a suburb of Melbourne, Australi...
# 307          Coldstream  Coldstream is a locality and township within G...
# 308         Cambarville  Cambarville is a bounded rural locality in Vic...
# 309             Emerald  Emerald is a suburb in the Greater Melbourne a...
# 310            Belgrave  Belgrave is a suburb in Melbourne, Victoria, A...
# 311             Areegra  Areegra is a small town in Victoria, Australia...
# 312              Beulah  Beulah is a town in the southern Mallee region...
# 313                Brim  Brim is a small town in the Wimmera region of ...
# 314            Hopetoun  Hopetoun is a town which serves as the major s...
#
#                                                 source                   image
# 0    http://upload.wikimedia.org/wikipedia/commons/...          Myrtleford.jpg
# 1    http://upload.wikimedia.org/wikipedia/en/thumb...              Bright.png
# 2    http://upload.wikimedia.org/wikipedia/commons/...          Porepunkah.jpg
# 3                                                 null                    null
# 4    http://upload.wikimedia.org/wikipedia/commons/...              Ararat.jpg
# 5    http://upload.wikimedia.org/wikipedia/commons/...             Moyston.jpg
# 6    http://upload.wikimedia.org/wikipedia/commons/...             Taytoon.png
# 7                                                 null                    null
# 8    http://upload.wikimedia.org/wikipedia/en/thumb...           Wendouree.jpg
# 9    http://upload.wikimedia.org/wikipedia/commons/...          Sebastopol.jpg
# 10   http://upload.wikimedia.org/wikipedia/commons/...           Alfredton.jpg
# 11   http://upload.wikimedia.org/wikipedia/commons/...    Ballarat Central.jpg
# 12   http://upload.wikimedia.org/wikipedia/en/thumb...              Rosana.jpg
# 13   http://upload.wikimedia.org/wikipedia/commons/...            Viewbank.png
# 14   http://upload.wikimedia.org/wikipedia/commons/...  Heidelberg Heights.png
# 15   http://upload.wikimedia.org/wikipedia/commons/...           Yallambie.png
# 16   http://upload.wikimedia.org/wikipedia/commons/...             Benalla.jpg
# 17                                                null                    null
# 18   http://upload.wikimedia.org/wikipedia/commons/...            Devenish.jpg
# 19   http://upload.wikimedia.org/wikipedia/commons/...           Goorambat.jpg
# 20   http://upload.wikimedia.org/wikipedia/commons/...           Aberfeldy.jpg
# 21   http://upload.wikimedia.org/wikipedia/commons/...             Athlone.png
# 22   http://upload.wikimedia.org/wikipedia/commons/...           Buln Buln.png
# 23   http://upload.wikimedia.org/wikipedia/commons/...              Darnum.png
# 24   http://upload.wikimedia.org/wikipedia/commons/...            Brighton.jpg
# 25   http://upload.wikimedia.org/wikipedia/commons/...         Sandringham.jpg
# 26   http://upload.wikimedia.org/wikipedia/commons/...           Moorabbin.jpg
# 27   http://upload.wikimedia.org/wikipedia/commons/...          Mordialloc.jpg
# 28   http://upload.wikimedia.org/wikipedia/commons/...         Baddaginnie.jpg
# 29   http://upload.wikimedia.org/wikipedia/commons/...             Benalla.jpg
# ..                                                 ...                     ...
# 285  http://upload.wikimedia.org/wikipedia/commons/...              Goroke.jpg
# 286  http://upload.wikimedia.org/wikipedia/en/thumb...            Gymbowen.png
# 287  http://upload.wikimedia.org/wikipedia/commons/...             Mitcham.jpg
# 288  http://upload.wikimedia.org/wikipedia/en/thumb...           Blackburn.jpg
# 289  http://upload.wikimedia.org/wikipedia/commons/...            Box Hill.jpg
# 290  http://upload.wikimedia.org/wikipedia/commons/...       Vermont South.png
# 291  http://upload.wikimedia.org/wikipedia/commons/...            Bundoora.jpg
# 292  http://upload.wikimedia.org/wikipedia/commons/...               Lalor.jpg
# 293  http://upload.wikimedia.org/wikipedia/commons/...              Epping.png
# 294  http://upload.wikimedia.org/wikipedia/en/thumb...              Mernda.png
# 295  http://upload.wikimedia.org/wikipedia/commons/...            Bandiana.png
# 296  http://upload.wikimedia.org/wikipedia/commons/...           Bonegilla.jpg
# 297  http://upload.wikimedia.org/wikipedia/commons/...             Wodonga.jpg
# 298  http://upload.wikimedia.org/wikipedia/commons/...      Gateway Island.png
# 299  http://upload.wikimedia.org/wikipedia/en/thumb...            Laverton.jpg
# 300  http://upload.wikimedia.org/wikipedia/commons/...             Tarneit.png
# 301  http://upload.wikimedia.org/wikipedia/en/thumb...            Werribee.png
# 302  http://upload.wikimedia.org/wikipedia/commons/...    Williams Landing.jpg
# 303  http://upload.wikimedia.org/wikipedia/en/thumb...          Abbotsford.jpg
# 304  http://upload.wikimedia.org/wikipedia/en/thumb...            Cremorne.png
# 305  http://upload.wikimedia.org/wikipedia/en/thumb...             Fitzroy.jpg
# 306  http://upload.wikimedia.org/wikipedia/en/thumb...         Collingwood.jpg
# 307  http://upload.wikimedia.org/wikipedia/commons/...          Coldstream.jpg
# 308  http://upload.wikimedia.org/wikipedia/commons/...         Cambarville.jpg
# 309  http://upload.wikimedia.org/wikipedia/en/thumb...             Emerald.jpg
# 310  http://upload.wikimedia.org/wikipedia/commons/...            Belgrave.jpg
# 311  http://upload.wikimedia.org/wikipedia/commons/...             Areegra.png
# 312  http://upload.wikimedia.org/wikipedia/commons/...              Beulah.jpg
# 313  http://upload.wikimedia.org/wikipedia/commons/...                Brim.jpg
# 314  http://upload.wikimedia.org/wikipedia/commons/...            Hopetoun.jpg
#
# [315 rows x 4 columns]
